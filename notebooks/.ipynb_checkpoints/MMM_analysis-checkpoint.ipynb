# %%
import pandas as pd
import numpy as np
import sys
import os

# Add parent directory to path
sys.path.insert(0, os.path.abspath('..'))

from src import BayesianMMMTrainer
import arviz as az
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Setup and Configuration

# %%
# Configure the Bayesian MMM
config = {
    'date_col': 'DATE',
    'spend_cols': ['tv_S', 'ooh_S', 'print_S', 'facebook_S', 'search_S'],
    'revenue_col': 'revenue',
    'control_cols': ['competitor_sales_B', 'newsletter'],
    'fourier_k': 3,
    'mcmc_params': {
        'draws': 1000,
        'tune': 1000,
        'target_accept': 0.9
    }
}

data_path = '../data/dt_simulated_weekly.csv'
holidays_path = '../data/dt_prophet_holidays.csv'

print("✓ Configuration loaded")

# %% [markdown]
# ## 2. Load Data

# %%
# Load and preview the data
df = pd.read_csv(data_path)
print(f"Data shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
df.head()

# %% [markdown]
# ## 3. Train Bayesian MMM

# %%
# Initialize and train the model
trainer = BayesianMMMTrainer(config, data_path, holidays_path)

try:
    roi_results = trainer.run_full_analysis(experiment_name='notebook_analysis')
    print("\n✓ Model training complete")
except Exception as e:
    print(f"✗ Error: {e}")
    roi_results = {}

# %% [markdown]
# ## 4. ROI Results

# %%
# Display ROI results
if roi_results:
    results_df = pd.DataFrame(roi_results).T
    print("Channel ROI Summary:")
    print(results_df[['unscaled_roi', 'mean_beta', 'mean_alpha']].round(3))
else:
    print("No results available")

# %% [markdown]
# ## 5. MCMC Diagnostics

# %%
# Check convergence diagnostics
if trainer.trace is not None:
    summary = az.summary(trainer.trace, var_names=['alpha', 'beta', 'sigma'])
    print(summary[['r_hat', 'mean']].round(3))
