# %%
import sys
sys.path.insert(0, '..')
from src import BayesianMMMTrainer
import pandas as pd

print("✓ Imports successful")

# %% [markdown]
# # Bayesian Marketing Mix Model

# %%
# Load data
df = pd.read_csv('../data/dt_simulated_weekly.csv')
print(f"Data shape: {df.shape}")
print(f"Columns: {list(df.columns)}")

# %%
# Setup config with CORRECT column names
config = {
    'date_col': 'DATE',
    'spend_cols': ['tv_S', 'ooh_S', 'print_S', 'facebook_S', 'search_S'],
    'revenue_col': 'revenue',
    'control_cols': ['competitor_sales_B', 'newsletter'],
    'fourier_k': 3,
    'mcmc_params': {'draws': 1000, 'tune': 1000, 'target_accept': 0.9}
}

# Initialize trainer
trainer = BayesianMMMTrainer(config, '../data/dt_simulated_weekly.csv', '../data/dt_prophet_holidays.csv')
print("✓ Trainer initialized")

# %%
# Load and preprocess (no MCMC)
trainer.load_data()
trainer.preprocess()
print("✓ Data loaded and preprocessed")
print(f"  Weeks: {len(trainer.data_df)}")
print(f"  Channels: {len(config['spend_cols'])}")

# %% [markdown]
# Note: Full MCMC training requires significant computation time. For demonstration, see examples/quickstart.py
