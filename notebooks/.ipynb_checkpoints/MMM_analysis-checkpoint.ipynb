# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src import BayesianMMMTrainer
import pandas as pd

# %% [markdown]
# # Bayesian Marketing Mix Model Analysis

# %%
# Load data
data_path = '../data/dt_simulated_weekly.csv'
df = pd.read_csv(data_path)
print(f"Data shape: {df.shape}")
print(f"Columns: {list(df.columns)}")

# %%
# Configuration
config = {
    'date_col': 'DATE',
    'spend_cols': ['tv_S', 'ooh_S', 'print_S', 'facebook_S', 'search_S'],
    'revenue_col': 'revenue',
    'control_cols': ['competitor_sales_B', 'newsletter'],
    'fourier_k': 3,
    'mcmc_params': {
        'draws': 1000,
        'tune': 1000,
        'target_accept': 0.9
    }
}

print("✓ Configuration ready")

# %%
# Initialize trainer
trainer = BayesianMMMTrainer(
    config,
    data_path,
    '../data/dt_prophet_holidays.csv'
)
print("✓ Trainer initialized")

# %%
# Run full analysis
try:
    roi_results = trainer.run_full_analysis()
    print("✓ Analysis complete")
except Exception as e:
    print(f"Error: {e}")
    roi_results = {}

# %%
# Display ROI results
if roi_results:
    results_df = pd.DataFrame(roi_results).T
    print(results_df[['unscaled_roi', 'mean_beta', 'mean_alpha']].round(3))
